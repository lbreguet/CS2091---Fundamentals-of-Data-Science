# %% [markdown]
# # Linear Regression
# Linear regression analysis is the most widely used of all statistical techniques: it is the study of linear, additive relationships between variables. It's widely used in various industries to create models, which will help in a business. For example, in the retail industry, there are various factors affecting the sale of a product. These factors could be the price, promotions, or seasonal factors, to name a few. A linear regression model helps in understanding the influence of each of these factors on the sales of a product as well as to calculate the baseline sales, which is basically the number of sales of this product in the event that there were no external factors, such as price, promotions, and so on.

# %% [markdown]
# ## Simple linear regression
#
# A simple linear regression has a single variable, and it can be described using the following formula:
#
# $y= A + Bx$
#
# Here, y is the dependent variable, x is the independent variable, A is the intercept (where x is to the power of zero) and B is the co-efficient

# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt

# %% [markdown]
# We have been loading different libraries routinely so far. What does it mean?
#
# #### Python's Modules and Libraries
#
# Python code can be executed interactively (i.e. Notebook) or written in a file. A file containing Python's definitions is called a module. These definitions can then be used in other Python's programs or notebooks in two ways:
#
# * By importing a module, you can refer to definitions inside this module in the following way

# %%
import numpy
ar = numpy.array([1, 2, 3])

import numpy as np
ar = np.array([1, 2, 3])

# %% [markdown]
# * By exposing the content of a module

# %%
from numpy import array
ar = array([1, 2, 3])

from numpy import array as arr
ar = arr([1, 2, 3])

# %% [markdown]
# Numpy's arrays are wrappers around Python's array and are the core data structure in Pandas.
#
# Each standard module in Python has documentation which specifies its definitions and how they should be used.
#
# For Numpy's arrays, you can find it here:
# https://docs.scipy.org/doc/numpy-1.13.0/reference/arrays.ndarray.html
#
# **Task:** Can you create a 2 dimensional (a table) numpy.array of the form [[1,0,0],[0,1,0],[0,0,1]]? Hint, look at https://docs.scipy.org/doc/numpy-1.13.0/reference/routines.array-creation.html#routines-array-creation

# %% [markdown]
# The dataset that we'll be using contains the height (cm) and weight (kg) of a sample of men.

# %%
wt_ht_data = pd.read_csv('https://raw.githubusercontent.com/AUP-CS2091/Week-6/master/nba_ht_wt.csv?token=AFj8VWzhyUB6MSri8YM9gPa83DW29vvPks5Z3-5swA%3D%3D')
wt_ht_data.head()
# Out:
#           Player Pos  Height  Weight  Age
# 0  Nate Robinson   G      69     180   29
# 1  Isaiah Thomas   G      69     185   24
# 2   Phil Pressey   G      71     175   22
# 3   Shane Larkin   G      71     176   20
# 4      Ty Lawson   G      71     195   25

# %% [markdown]
# The following code ingests the data and creates a simple scatter plot in order to understand the distribution of the weight versus the height:

# %%
fig, ax = plt.subplots(1, 1) 
ax.scatter(wt_ht_data['Height'],wt_ht_data['Weight'])
ax.set_xlabel('Height')
ax.set_ylabel('Weight')
plt.show()

# %% [markdown]
# From the plot, you can see that there is a linear relationship between the weight and height of the individual.

# %% [markdown]
# Visualization is a very integral part of data science. It helps in communicating a pattern or a relationship that cannot be seen by looking at raw data. It's easier for a person to remember a picture and recollect it as compared to lines of text. This holds true for data too.
#
# There are many properties of a line that can be set, such as the color, dashes, and several others. There are essentially three ways of doing this. Let's take a simple line chart as an example:

# %%
plt.plot([1,2,3,4], [1,4,9,16])
plt.show()

# %% [markdown]
# We can use arguments within the plot function to set the property of the line:

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], linewidth=4.0)  # increasing # the line width
plt.show()

# %% [markdown]
# The plot function returns the list of line objects. Using the line setter method of line objects we can define the property that needs to be set:

# %%
line, = plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
line.set_linestyle('--') # Setting dashed lines
plt.show()

# %% [markdown]
# We can also refer directly to the plot created. The following create a figure containing one (sub)plot (one row and one column). It also returns the plot (or an array of plots if more than one was created in the figure).

# %%
fig, ax = plt.subplots(1, 1)

# %% [markdown]
# And then use the plot for plotting or scattering your data

# %%
ax.scatter([1,2,3],[4,5,6])
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.show()

# %% [markdown]
# Let's see how the variables are correlated to each other as follows:

# %%
wt_ht_data.corr()
# Out:
#           Height    Weight       Age
# Height  1.000000  0.820719  0.005010
# Weight  0.820719  1.000000  0.109814
# Age     0.005010  0.109814  1.000000

# %% [markdown]
# We can clearly see that the height and weight are correlated to each other based on a Pearson correlation value coefficient of 0.82 . A Pearson correlation ranges from -1 to +1, so when the number is more positive, the relation between the two variables is much stronger if they increase or decrease together. If the correlation value is negative, then the relation between the two variables is strong, but is in the opposite direction.

# %% [markdown]
# ![Pearson](https://en.wikipedia.org/wiki/Pearson_correlation_coefficient#/media/File:Correlation_coefficient.png)

# %% [markdown]
# Let's generate a linear regression model with the weight as the dependent variable and x as the independent variable:

# %%
from sklearn import linear_model
X = wt_ht_data[['Height']]
Y = wt_ht_data['Weight']
lm = linear_model.LinearRegression()
lm.fit(X, Y)
print('Intercept is ' + str(lm.intercept_) + '\n')
print('Coefficient value of the height is ' + str(lm.coef_) + '\n')
print(pd.DataFrame(list(zip(X.columns,lm.coef_)), 
                   columns = ['features', 'estimatedCoefficients']))
# Out:
# Intercept is -279.869317362
#
# Coefficient value of the height is [ 6.33074547]
#
#   features  estimatedCoefficients
# 0   Height               6.330745

# %% [markdown]
# In the preceding code, we use linear_model.LinearRegression() to create a linear regression object, lm. We then use the fit() method of lm to define the dependent and independent variable, where in our case, the weight is the dependent variable and the height is the independent variable.
#
# To get the intercept value, we use lm.intercept_, and to get the coefficient, we use the lm.coef.
#
# The last line of the code helps in creating a DataFrame of the independent variable and its corresponding coefficients. This will be useful when we explore multiple regression in detail.

# %% [markdown]
# The zip function zips together two lists. We need to convert it back to a list.

# %%
ar1 = [1,2,3]
ar2 = [4,5,6]
list(zip(ar1,ar2))
# Out:
# [(1, 4), (2, 5), (3, 6)]

# %% [markdown]
# We'll now plot the scatter chart again with a trend line:

# %%
fig, ax = plt.subplots(1, 1) 
ax.scatter(X,Y)
ax.plot(X,lm.predict(wt_ht_data.Height[:, np.newaxis]), 
                   color = 'red')
ax.set_xlabel('Height')
ax.set_ylabel('Weight')
plt.show()

# %% [markdown]
# The predict function expects a 3 dimensional array containing the instances and features to use for prediction and returns the prediction. What are the instances and features in this case?
#
# How can we generate from X, which is a dataframe, the required two dimensional array? One option is to convert the (1 column) dataframe into a list and then increase the list dimension by one. This is obtained by slicing: https://docs.scipy.org/doc/numpy-1.13.0/reference/arrays.indexing.html

# %% [markdown]
# ## Multiple regression
# Multiple linear regression occurs when more than one independent variable is used to predict a dependent variable:
#
# $Y = a + b_1x_1 + b_2x_2 + \ldots + b_nx_n$
#
# Multiple regression
# Where, Y is the dependent variable, a is the intercept, b1 and b2 are the coefficients, and x1 and x2 are the independent variables
#
# To build the multiple linear regression model, we'll utilize the NBA's basketball data to predict the average points scored per game

# %%
nba_data = pd.read_csv('https://raw.githubusercontent.com/AUP-CS2091/Week-6/master/NBApoints.csv?token=AFj8VRba8vPgAP2kY5ATlQtf3HkESD05ks5Z3-7HwA%3D%3D')
nba_data.head()
# Out:
#    Rk            Player Pos  Age   Tm   G  GS    MP    FG   FGA  ...     FT%  \
# 0   1     Stephen Curry  PG   27  GSW  79  79  34.2  10.2  20.2  ...   0.908
# 1   2      James Harden  SG   26  HOU  82  82  38.1   8.7  19.7  ...   0.860
# 2   3      Kevin Durant  SF   27  OKC  72  72  35.8   9.7  19.2  ...   0.898
# 3   4  DeMarcus Cousins   C   25  SAC  65  65  34.6   9.2  20.5  ...   0.718
# 4   5      LeBron James  SF   31  CLE  76  76  35.6   9.7  18.6  ...   0.731
#
#    ORB  DRB   TRB  AST  STL  BLK  TOV   PF  PS/G
# 0  0.9  4.6   5.4  6.7  2.1  0.2  3.3  2.0  30.1
# 1  0.8  5.3   6.1  7.5  1.7  0.6  4.6  2.8  29.0
# 2  0.6  7.6   8.2  5.0  1.0  1.2  3.5  1.9  28.2
# 3  2.4  9.1  11.5  3.3  1.6  1.4  3.8  3.6  26.9
# 4  1.5  6.0   7.4  6.8  1.4  0.6  3.3  1.9  25.3
#
# [5 rows x 30 columns]

# %% [markdown]
# The following are some of the column descriptions of the data:
#
# * Age: This refers to the age
# * G: This refers to the games played
# * FG%: This refers to the percentage of successful field goals (out of 100 that were attempted)
# * FT%: This refers tot the percentage of successful free throws (out of 100 that were attempted)
# * PS/G: This refers to the average points scored per game
#
# Check https://stats.nba.com/help/glossary/ for full descriptions
#
# We use the descibe() method of the DataFrame to get the univariate metrics on each of the fields:

# %%
nba_data.describe()
# Out:
#                Rk         Age           G          GS          MP          FG  \
# count  476.000000  476.000000  476.000000  476.000000  476.000000  476.000000
# mean   238.500000   26.594538   54.785714   25.840336   20.160084    3.113235
# std    137.553626    4.382440   24.274576   29.413419    9.218341    2.053724
# min      1.000000   19.000000    1.000000    0.000000    2.000000    0.000000
# 25%    119.750000   23.000000   37.000000    1.000000   13.000000    1.500000
# 50%    238.500000   26.000000   62.000000   10.000000   19.950000    2.700000
# 75%    357.250000   29.000000   76.000000   53.000000   28.025000    4.400000
# max    476.000000   39.000000   82.000000   82.000000   42.000000   10.200000
#
#               FGA         FG%          3P         3PA     ...             FT%  \
# count  476.000000  475.000000  476.000000  476.000000     ...      462.000000
# mean     6.951891    0.444091    0.688025    1.963866     ...        0.741426
# ...

# %% [markdown]
# ### Making Initial Observations
#
# Using the above data, we can immediately learn several things.
#
# **Question 1: ** answer the following questions
#
# * What is the average age of a player?
#   <p style="color:red">26.6 years old</p>
# * The age of the youngest player
#   <p style="color:red">19 years old</p>
# * The oldest player
#   <p style="color:red">39 years old</p>
# * Minimal number of games played by a player
#   <p style="color:red">1 game</p>
# * Most games played by a player
#   <p style="color:red">82 games</p>
# * Best field goal percentage for a player
#   <p style="color:red">100%</p>
# * Worst field goal percentage for a player
#   <p style="color:red">0%</p>
# * Average field goal attempt for a player
#   <p style="color:red">44.4%</p>
# * What can you infer from the small standard derivation?
#   <p style="color:red">Most of the players scored between 36% and 52%.</p>
# * Are there very bad free throw shooters? How bad?
#   <p style="color:red">Yes, there are bad free throw shooters. The worst one has 0% free throw accuracy.</p>
# * And the best free throw shooter?
#   <p style="color:red">100%</p>
# * What is the range of the free throw success of most players?
#   <p style="color:red">14.45%</p>
# * What is the highest score per game?
#   <p style="color:red">30.1</p>
# * And the least?
#   <p style="color:red">0</p>
# * And on average?
#   <p style="color:red">8.35</p>
#
# ** Question 2:** Check the correlation between the different variables. What is the highest correlation? With regard to goals made? With average points per game?

# %%
nba_data.corr()
# Out:
#             Rk       Age         G        GS        MP        FG       FGA  \
# Rk    1.000000 -0.015434 -0.625744 -0.710564 -0.931477 -0.945782 -0.943606
# Age  -0.015434  1.000000  0.053128  0.033827  0.050074 -0.002139 -0.002291
# G    -0.625744  0.053128  1.000000  0.592741  0.650809  0.542592  0.525471
# GS   -0.710564  0.033827  0.592741  1.000000  0.782503  0.732302  0.710605
# MP   -0.931477  0.050074  0.650809  0.782503  1.000000  0.885680  0.895299
# FG   -0.945782 -0.002139  0.542592  0.732302  0.885680  1.000000  0.977520
# FGA  -0.943606 -0.002291  0.525471  0.710605  0.895299  0.977520  1.000000
# FG%  -0.200693  0.055498  0.207429  0.191264  0.132219  0.228186  0.070600
# 3P   -0.586543  0.063140  0.368579  0.415153  0.579024  0.539814  0.634490
# 3PA  -0.592163  0.055795  0.373937  0.413314  0.591266  0.537947  0.648409
# 3P%  -0.217720 -0.005406  0.163235  0.098570  0.203935  0.174523  0.215000
# ...

# %% [markdown]
# <p style="color:red">Highest correlation is `0.986554` and that is in regards to average points scored per game and successful field goals.</p>

# %% [markdown]
# **Question 3:** Plot the distribution age and points per game. Is there a clear pattern?

# %%
from sklearn import linear_model
X = nba_data[['Age']]
Y = nba_data['PS/G']
lm = linear_model.LinearRegression()
lm.fit(X, Y)

fig, ax = plt.subplots(1, 1) 
ax.scatter(X,Y)
ax.plot(X,lm.predict(nba_data.Age[:, np.newaxis]), color = 'red')
ax.set_xlabel('Age')
ax.set_ylabel('Average Points per Game')
plt.show()

# %% [markdown]
# <p style="color: red">There is no clear pattern between these attributes. Doesn't matter how old you are, you can still score points.</p>

# %% [markdown]
# **Question 4:** Plot six more distributions and try to find those which make most sense

# %%
from sklearn import linear_model
X = nba_data[['FG']]
Y = nba_data['G']
lm = linear_model.LinearRegression()
lm.fit(X, Y)

fig, ax = plt.subplots(1, 1) 
ax.scatter(X,Y)
ax.plot(X,lm.predict(nba_data.FG[:, np.newaxis]), color = 'red')
ax.set_xlabel('Field Goals')
ax.set_ylabel('Games Played')
plt.show()

# %%
from sklearn import linear_model
X = nba_data[['DRB']]
Y = nba_data['AST']
lm = linear_model.LinearRegression()
lm.fit(X, Y)

fig, ax = plt.subplots(1, 1) 
ax.scatter(X,Y)
ax.plot(X,lm.predict(nba_data.DRB[:, np.newaxis]), color = 'red')
ax.set_xlabel('Dribbles')
ax.set_ylabel('Assists')
plt.show()

# %%
from sklearn import linear_model
X = nba_data[['G']]
Y = nba_data['PS/G']
lm = linear_model.LinearRegression()
lm.fit(X, Y)

fig, ax = plt.subplots(1, 1) 
ax.scatter(X,Y)
ax.plot(X,lm.predict(nba_data.G[:, np.newaxis]), color = 'red')
ax.set_xlabel('Games Played')
ax.set_ylabel('Average Points per Game')
plt.show()

# %%
from sklearn import linear_model
X = nba_data[['Age']]
Y = nba_data['G']
lm = linear_model.LinearRegression()
lm.fit(X, Y)

fig, ax = plt.subplots(1, 1) 
ax.scatter(X,Y)
ax.plot(X,lm.predict(nba_data.Age[:, np.newaxis]), color = 'red')
ax.set_xlabel('Age')
ax.set_ylabel('Average Points per Game')
plt.show()

# %%
from sklearn import linear_model
X = nba_data[['FG']]
Y = nba_data['3P']
lm = linear_model.LinearRegression()
lm.fit(X, Y)

fig, ax = plt.subplots(1, 1) 
ax.scatter(X,Y)
ax.plot(X,lm.predict(nba_data.FG[:, np.newaxis]), color = 'red')
ax.set_xlabel('Field Goals')
ax.set_ylabel('3-Pointers')
plt.show()

# %%
from sklearn import linear_model
X = nba_data[['FG']]
Y = nba_data['2P']
lm = linear_model.LinearRegression()
lm.fit(X, Y)

fig, ax = plt.subplots(1, 1) 
ax.scatter(X,Y)
ax.plot(X,lm.predict(nba_data.FG[:, np.newaxis]), color = 'red')
ax.set_xlabel('Field Goals')
ax.set_ylabel('2-Pointers')
plt.show()

# %% [markdown]
# ## Training a model
#
#
# We'll learn how to build the linear regression models using the following packages:
#
# * The statsmodels module
# * The SciKit package
#
# Even pandas provides an Ordinary Least Square (OLS) regression, which you can experiment with after you've completed this chapter. The ordinary least square is a method to estimate unknown coefficients and intercepts for a regression equation. We'll start off the with the statsmodels package. The statsmodels is a Python module that allows users to explore data, estimate statistical models, and perform statistical tests. An extensive list of descriptive statistics, statistical tests, plotting functions, and result statistics is available for different types of data and each estimator.
#
# But first, let us break the data into target and features and delete the unimportant feature Player and Team and normalize Position.

# %%
nba_data = pd.read_csv('./NBApoints.csv')

del nba_data['Player']
del nba_data['Tm']
nba_data['Pos'] = nba_data['Pos'].astype('category').cat.codes

# %% [markdown]
# One way to convert a categorical value into a number is to take its categorical code (starting from 0).
#
# We also need to deal with empty values. We first check which columns contain such empty values and then use the mean to fill all such columns.

# %%
print(pd.isnull(nba_data).sum() > 0)
nba_data = nba_data.fillna(nba_data.mean())
print(pd.isnull(nba_data).sum() > 0)
# Out:
# Rk      False
# Pos     False
# Age     False
# G       False
# GS      False
# MP      False
# FG      False
# FGA     False
# FG%      True
# 3P      False
# 3PA     False
# 3P%      True
# 2P      False
# 2PA     False
# 2P%      True
# eFG%     True
# FT      False
# FTA     False
# FT%      True
# ORB     False
# DRB     False
# TRB     False
# AST     False
# STL     False
# BLK     False
# TOV     False
# PF      False
# PS/G    False
# dtype: bool
# Rk      False
# Pos     False
# Age     False
# G       False
# GS      False
# MP      False
# FG      False
# FGA     False
# FG%     False
# 3P      False
# 3PA     False
# 3P%     False
# 2P      False
# 2PA     False
# 2P%     False
# eFG%    False
# FT      False
# FTA     False
# FT%     False
# ORB     False
# DRB     False
# TRB     False
# AST     False
# STL     False
# BLK     False
# TOV     False
# PF      False
# PS/G    False
# dtype: bool

# %% [markdown]
# How can we select as features all columns except Age? The loc function of dataframes allows us to choose all rows and columns for specific columns as follows.
#
# We also need to convert values to float for modeling purposes (some values are integers right now).

# %%
X = nba_data.loc[:, nba_data.columns != 'Age'].astype('float')
y = nba_data['Age']

# %%
import statsmodels.formula.api as sm
from statsmodels.tools.tools import add_constant

result = sm.OLS( y, add_constant(X) ).fit()

# %% [markdown]
# The OLS function helps in creating the linear regression object with a dependent and independent variable. The fit() method helps in fitting the model. Note that there is a add_constant() function, which is used to calculate the intercept while creating the model. By default, the OLS() function won't calculate the intercept, and it has to be explicitly mentioned with the the help of the add_constant function.

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    Age   R-squared:                       0.172
# Model:                            OLS   Adj. R-squared:                  0.122
# Method:                 Least Squares   F-statistic:                     3.440
# Date:                Mon, 09 Oct 2017   Prob (F-statistic):           3.51e-08
# Time:                        16:42:13   Log-Likelihood:                -1333.4
# No. Observations:                 476   AIC:                             2723.
# Df Residuals:                     448   BIC:                             2839.
# Df Model:                          27
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         17.4283      4.624      3.769      0.000       8.341      26.515
# ...

# %% [markdown]
# The preceding summary gives quite a lot of information about the model. The main parameter to look for is the r square value, which tells you how much of the variance of the dependent variable is captured by the model. It ranges from 0 to 1, and the p value tells us if the model is significant.
#
# From the preceding output, we can see that the R-square value is 0.172, which isn't great. We can see that the model shows eFG% as the most significant variable, which is the Effective Field Goal Percentage variable. As a rule of thumb, any p value of a variable less than 0.05 can be considered significant.

# %% [markdown]
# Let's recreate the model with only the successful field goals variable and see how the model performs:

# %%
result_alternate = sm.OLS( y, add_constant(X['FG%']) ).fit()
result_alternate.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    Age   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.459
# Date:                Mon, 09 Oct 2017   Prob (F-statistic):              0.228
# Time:                        16:42:13   Log-Likelihood:                -1377.5
# No. Observations:                 476   AIC:                             2759.
# Df Residuals:                     474   BIC:                             2767.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         25.3326      1.064     23.815      0.000      23.242      27.423
# ...

# %% [markdown]
# We can see that the variable has become less significant, and the r square value has become really low. The preceding model can be iterated multiple times with the different combination of variables till the best model is arrived at.
#
# The model that gives the least mean squared error is a good model.
#
# We can also create models directly using the required formula (without weights, of course!)

# %%
import statsmodels.formula.api as smf
est = smf.ols(formula="TRB ~ AST + STL + BLK", data=nba_data).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    TRB   R-squared:                       0.634
# Model:                            OLS   Adj. R-squared:                  0.632
# Method:                 Least Squares   F-statistic:                     272.9
# Date:                Mon, 09 Oct 2017   Prob (F-statistic):          1.10e-102
# Time:                        16:42:13   Log-Likelihood:                -853.73
# No. Observations:                 476   AIC:                             1715.
# Df Residuals:                     472   BIC:                             1732.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.0288      0.128      8.020      0.000       0.777       1.281
# ...

# %% [markdown]
# The preceding model was constructed using the statsmodels package. We'll now build a model using SciKit.
#
# The following code creates a Linear Regression object and then fits it with dependent and independent variables:

# %%
from sklearn import linear_model

lm = linear_model.LinearRegression()

lm.fit(X, y)
 
pd.DataFrame(list(zip(X.columns,lm.coef_)), columns = ['features', 'estimatedCoefficients'])
# Out:
#    features  estimatedCoefficients
# 0        Rk               0.005677
# 1       Pos              -0.467502
# 2         G               0.000634
# 3        GS               0.003585
# 4        MP               0.132595
# 5        FG              -1.779660
# 6       FGA              -9.472740
# 7       FG%             -16.792151
# 8        3P               0.534360
# 9       3PA               9.326686
# 10      3P%              -3.906015
# 11       2P               0.665034
# 12      2PA               9.644347
# 13      2P%               1.761496
# 14     eFG%              23.234297
# 15       FT               0.103110
# 16      FTA              -0.274041
# 17      FT%               4.371426
# 18      ORB               8.355298
# 19      DRB              10.141802
# 20      TRB              -9.704109
# 21      AST               0.917361
# 22      STL              -1.050025
# 23      BLK              -0.600137
# 24      TOV              -2.513656
# 25       PF               1.059280
# ...

# %% [markdown]
# The coefficient are similar to the model that was built using the statsmodels package.

# %% [markdown]
# **Question 5:** Build 3 more models for predicting PS/G and try to find the best one

# %%
X = nba_data.loc[:, nba_data.columns != 'PS/G'].astype('float')
y = nba_data['PS/G']

import statsmodels.formula.api as sm
from statsmodels.tools.tools import add_constant

result = sm.OLS( y, add_constant(X) ).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   PS/G   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 9.959e+04
# Date:                Mon, 09 Oct 2017   Prob (F-statistic):               0.00
# Time:                        16:42:13   Log-Likelihood:                 571.21
# No. Observations:                 476   AIC:                            -1086.
# Df Residuals:                     448   BIC:                            -969.8
# Df Model:                          27
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1752      0.086     -2.048      0.041      -0.343      -0.007
# ...

# %%
result_alternate = sm.OLS( y, add_constant(X['FG']) ).fit()
result_alternate.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   PS/G   R-squared:                       0.973
# Model:                            OLS   Adj. R-squared:                  0.973
# Method:                 Least Squares   F-statistic:                 1.727e+04
# Date:                Mon, 09 Oct 2017   Prob (F-statistic):               0.00
# Time:                        16:42:13   Log-Likelihood:                -637.21
# No. Observations:                 476   AIC:                             1278.
# Df Residuals:                     474   BIC:                             1287.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1041      0.077     -1.351      0.177      -0.255       0.047
# ...

# %%
nba_data.columns = nba_data.columns.str.replace('/','slash')

import statsmodels.formula.api as smf
est = smf.ols(formula='PSslashG ~ FG + FT + G', data=nba_data).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               PSslashG   R-squared:                       0.989
# Model:                            OLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                 1.393e+04
# Date:                Mon, 09 Oct 2017   Prob (F-statistic):               0.00
# Time:                        16:42:14   Log-Likelihood:                -429.74
# No. Observations:                 476   AIC:                             867.5
# Df Residuals:                     472   BIC:                             884.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0174      0.069     -0.253      0.800      -0.152       0.117
# ...

# %% [markdown]
# **Question 6:** Build the best model you can for predicting AST

# %%
X = nba_data.loc[:, nba_data.columns != 'AST'].astype('float')
y = nba_data['AST']

import statsmodels.formula.api as sm
from statsmodels.tools.tools import add_constant

result = sm.OLS( y, add_constant(X) ).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    AST   R-squared:                       0.825
# Model:                            OLS   Adj. R-squared:                  0.815
# Method:                 Least Squares   F-statistic:                     78.25
# Date:                Mon, 09 Oct 2017   Prob (F-statistic):          4.75e-151
# Time:                        16:42:14   Log-Likelihood:                -528.27
# No. Observations:                 476   AIC:                             1113.
# Df Residuals:                     448   BIC:                             1229.
# Df Model:                          27
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.6686      0.862     -1.936      0.053      -3.362       0.025
# ...

# %% [markdown]
# Let's try to use our models to predict different values for players from the European league.

# %%
nba_data.columns = nba_data.columns.str.replace('%','prc')
nba_data.columns = nba_data.columns.str.replace('2','two')
nba_data.columns = nba_data.columns.str.replace('3','three')

est = smf.ols(formula="STL ~ threePprc + AST", data=nba_data).fit()

ndcolo = pd.DataFrame(index=[0], data={'threePprc': (43/101*100), 'AST': (110/28)})

ypred = est.predict(add_constant(ndcolo))
print(ypred)
# Out:
# 0    7.000349
# dtype: float64

# %% [markdown]
# **Question 7:** Can you improve the above model so the number of steals will be closer to the observed value (1)?

# %%
nba_data.columns = nba_data.columns.str.replace('%','prc')
nba_data.columns = nba_data.columns.str.replace('2','two')
nba_data.columns = nba_data.columns.str.replace('3','three')

est = smf.ols(formula="STL ~ threePprc + AST", data=nba_data).fit()

ndcolo = pd.DataFrame(index=[0], data=nba_data)

ypred = est.predict(add_constant(ndcolo))
print(ypred)
# Out:
# 0    1.518118
# dtype: float64
