# %% [markdown]
# # Project - Estimating the likelihood for an affair
#
# ## Details
#
# * Student ID
# ...
#
# ## Description of the project
#
# In this project, I was interested in answering the question "How likely is somebody to have an extramartial affair. To answer this question, I have decided a survey of 8 features and 1 target variable as follows:
#
# * sex factor indicating gender.
# * age numeric variable coding age in years.
# * ym numeric variable coding number of years married.
# * child factor. Are there children in the marriage?
# * religious numeric variable coding religiousness: 1 = anti, 2 = not at all, 3 = slightly, 4 = somewhat, 5 = very.
# * education numeric variable coding level of education: 9 = grade school, 12 = high school graduate, 14 = some college, 16 = college graduate, 17 = some graduate work, 18 = master’s degree, 20 = Ph.D., M.D., or other advanced degree.
# * occupation numeric variable coding occupation according to [Hollingshead classification](https://dictionary.fitbir.nih.gov/portal/publicData/dataElementAction!view.action?dataElementName=HollingsheadJobClassCat&publicArea=true) (reverse numbering).
# * rate numeric variable coding self rating of marriage: 1 = very unhappy, 2 = somewhat unhappy, 3 = average, 4 = happier than average, 5 = very happy
#
# The target variable - nbaffairs - was the number of extramarital encounters during the last year

# %%
import pandas as pd

data = pd.read_csv('https://raw.githubusercontent.com/AUP-CS2091/Week-10/master/Fair.csv')

data.head()
# Out:
#    sex  age       ym  child  religious  education  occupation  rate  nbaffairs
# 0    1   35  10.0000      0          3         18           7     4          0
# 1    0   28   5.0000      0          4         14           6     4          0
# 2    0   30  15.0000      1          1         12           1     4          0
# 3    1   66  20.0000      1          5         18           6     5          0
# 4    1   22   0.7497      0          2         17           6     3          0

# %% [markdown]
# I first needed to clean a bit the data, change categories into numbers and deal with missing values.

# %%
data['sex'] = data['sex'].astype('category').cat.codes
data['child'] = data['child'].astype('category').cat.codes

# %% [markdown]
# ## Data Exploation
#
# I wanted to better understand the distribution of the data and significance of different features

# %%
data.describe()
# Out:
#               sex        age          ym       child   religious   education  \
# count  601.000000  601.00000  601.000000  601.000000  601.000000  601.000000
# mean     0.475874   32.91015   10.049069    0.715474    3.116473   16.166389
# std      0.499834   10.77738    8.419986    0.451564    1.167509    2.402555
# min      0.000000   17.00000    0.000000    0.000000    1.000000    9.000000
# 25%      0.000000   25.00000    3.000000    0.000000    2.000000   14.000000
# 50%      0.000000   31.00000    8.000000    1.000000    3.000000   16.000000
# 75%      1.000000   37.00000   16.000000    1.000000    4.000000   18.000000
# max      1.000000   80.00000   29.000000    1.000000    5.000000   20.000000
#
#        occupation        rate   nbaffairs
# count  601.000000  601.000000  601.000000
# mean     4.194676    3.931780    1.455907
# std      1.819443    1.103179    3.298758
# min      1.000000    1.000000    0.000000
# 25%      3.000000    3.000000    0.000000
# 50%      5.000000    4.000000    0.000000
# 75%      6.000000    5.000000    0.000000
# max      7.000000    5.000000   12.000000

# %% [markdown]
# As can be seen, gender is distributed almost evenly between females and males with a slight advantage to females. Here is the precise distribution

# %%
females = len(data[data['sex'] == 0])
female_dist = females / len(data)
print(female_dist)

print(len(data[data['age'] == 37]))
# Out:
# 0.5241264559068219
# 19

# %% [markdown]
# The distribution of females in the US is 50.8% of the population in 2010 (see [this document](https://www.census.gov/prod/cen2010/briefs/c2010br-03.pdf)) so we have a relatively balaned dataset with regard to this feature.
#
# We can similarly see that 71% have children. I found in [this document](https://www.census.gov/prod/2013pubs/p20-570.pdf), that out of 55,519,648 married couples, 24,056,766 had children in the US, which gives us

# %%
print('{}%'.format(24056766/55519648*100))
# Out:
# 43.33018465823126%

# %% [markdown]
# only. One should, of course, take into account the number of children and the years of being married when trying to evaluate the distribution and this is outside of the scope of our course.
#
# For the rest of the features, I need to use different graphs for better understanding the distribution.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

_ = plt.hist(data['age'], 63)

# %% [markdown]
# I have compared it with [this distribution](https://www.census.gov/prod/2005pubs/p70-97.pdf). Unfortunately, the distribution does not talk about ages of people who are married but the age when they got married. Luckily, I found I can engineer my data to produce this information as follows

# %%
# age when married
data['awm'] = data.apply(lambda x: x['age'] - x['ym'], axis=1)

_ = plt.hist(data['awm'], 63)

# %% [markdown]
# The data is not "smooth" enough and can confuse a modeling technique because of ....
# A possible "smoothing" of the distribution is by assigning the ages into few categories

# %%
data['age_cats'] = data.apply(lambda x: 10 if x['awm'] == 11
         else 15 if x['awm'] > 10 and x['awm'] < 16
         else 20 if x['awm'] > 15 and x['awm'] < 21
         else 22 if x['awm'] > 20 and x['awm'] < 23
         else 24 if x['awm'] > 22 and x['awm'] < 25
         else 26 if x['awm'] > 24 and x['awm'] < 27
         else 30 if x['awm'] > 26 and x['awm'] < 31
         else 35 if x['awm'] > 30 and x['awm'] < 36
         else 45 if x['awm'] > 35 and x['awm'] < 50
         else 55, axis = 1)

_ = plt.hist(data['age_cats'], 10)

# %% [markdown]
# Similarly to age, I used the [same document](https://www.census.gov/prod/2005pubs/p70-97.pdf) for the duration of marriage...

# %%
data['ym_cats'] = data.apply(lambda x: 0 if x['ym'] < 3
         else 4 if x['ym'] > 2 and x['ym'] < 6
         else 7 if x['ym'] > 5 and x['ym'] < 9
         else 10 if x['ym'] > 8 and x['ym'] < 12
         else 13 if x['ym'] > 11 and x['ym'] < 15
         else 16 if x['ym'] > 14 and x['ym'] < 19
         else 19 if x['ym'] > 17 and x['ym'] < 21
         else 22 if x['ym'] > 20 and x['ym'] < 24
         else 25 if x['ym'] > 23 and x['ym'] < 27
         else 28 if x['ym'] > 26 and x['ym'] < 31
        else 29, axis = 1)


_ = plt.hist(data['ym_cats'], 10)

# %% [markdown]
# I go on and show the distribution of the rest of the features and try to explain any big anomality (of course, given a small data set, the anomalities will be bigger) as much as I can. I engineer features which are easier to compare to censuses I found online and smooth them when necessary.

# %% [markdown]
# I now check the distribution of the number of affairs

# %%
_ = plt.hist(data['nbaffairs'], 15)

# %% [markdown]
# The above histogram hints that it will be much more interesting in checking if an affair took place than to check the number of affairs. I do the required normalization

# %%
data['has_affair'] = data.apply(lambda x: 0 if x['nbaffairs'] == 0
         else 1, axis = 1)

_ = plt.hist(data['has_affair'], 2)

# %% [markdown]
# ## Modeling
#
# After a first attempt at engineering the data (and understanding I will probably need to reiterate the features engineering step in order to try to improve my models), I can try to build the models.
#
# First, separating the set of features and target variable.We should also remove the 'nbaffairs' from X because it is highly correlated and we dont have access to it in future cases.

# %%
X = data.loc[:, data.columns != 'has_affair']
del X['nbaffairs']
y = data['has_affair']

# %% [markdown]
# Next, I put aside 20% of the data for testing and comparing the set of final models I will obtain at the end.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# Since it is a classification problem, we can try first to use classification trees and to get the best parameters

# %%
from sklearn.tree import DecisionTreeClassifier

from sklearn.model_selection import cross_val_score

import numpy as np

rng = np.arange(1,5,1)
acc = []
for s in rng:
    model = DecisionTreeClassifier(max_depth=s)
    acc.append(cross_val_score(model, X_train, y_train).mean())

_ = plt.scatter(rng, acc, c='red')

# %%
rng = np.arange(1,8,1)
acc = []
for s in rng:
    model = DecisionTreeClassifier(max_depth=s)
    acc.append(cross_val_score(model, X_train, y_train).mean())

_ = plt.scatter(rng, acc, c='red')

# %% [markdown]
# If I choose to restrict the model with max_depth, 2 is apparently the best value in order to avoid over-fitting.
#
# I obtain the accuracy score on the test set while building a model using the whole training set

# %%
from sklearn.metrics import accuracy_score

model = DecisionTreeClassifier(max_depth=2)
model.fit(X_train,y_train)
accuracy_score(y_test,model.predict(X_test))
# Out:
# 0.71900826446280997

# %% [markdown]
# I continue with evaluating and comparing models with different parameters and techniques, while closely monitoring the documentation! I also try to remove features as some methods (i.e. nearest neighbors) are more sensitive to that.
#
# At the end, I choose the best model I could find and I want to know if I had enough data. For that, I plot the lurning_curves of each of the modeling techniques. Maybe a bit more data for logistic regression would give me much better classification, or for trees?

# %%
from sklearn.model_selection import learning_curve

x_example = X_train[:50]
y_example = y_train[:50]
train_sizes, train_scores, test_scores = learning_curve(model, x_example, y_example, cv=5)
plt.scatter(train_sizes, np.mean(test_scores, axis=1), c='red')
mean_values = np.mean(test_scores, axis=1)

# %% [markdown]
# It seems that our model can still benefit from more data but that this is not that crucial, i.e. we cans till get interesting results with the amount of data we have so far.

# %% [markdown]
# We are still not done, can we find interesting patterms using an unsupervised technique?

# %%
data.head()
# Out:
#    sex  age       ym  child  religious  education  occupation  rate  \
# 0    1   35  10.0000      0          3         18           7     4
# 1    0   28   5.0000      0          4         14           6     4
# 2    0   30  15.0000      1          1         12           1     4
# 3    1   66  20.0000      1          5         18           6     5
# 4    1   22   0.7497      0          2         17           6     3
#
#    nbaffairs      awm  age_cats  ym_cats  has_affair
# 0          0  25.0000        26       10           0
# 1          0  23.0000        24        4           0
# 2          0  15.0000        15       16           0
# 3          0  46.0000        45       19           0
# 4          0  21.2503        22        0           0

# %%
from sklearn.cluster import AgglomerativeClustering

clusters = AgglomerativeClustering(n_clusters=10)
arr = clusters.fit_predict(data[['age', 'child', 'education', 'occupation', 'sex']])

data['cluster'] = arr

data.sort_values('cluster')

data.groupby('cluster').mean()
# Out:
#               sex        age         ym     child  religious  education  \
# cluster
# 0        0.441176  41.411765  18.692401  0.926471   3.500000  15.514706
# 1        0.555556  50.222222  19.400000  0.888889   3.555556  15.955556
# 2        0.324561  21.649123   2.247016  0.289474   2.842105  15.043860
# 3        0.666667  78.111111  19.666667  0.888889   3.444444  16.000000
# 4        0.166667  28.023810   7.391861  0.857143   3.226190  14.428571
# 5        0.594203  32.565217   9.869565  0.797101   3.115942  17.811594
# 6        0.836364  37.290909  15.745455  0.909091   3.163636  19.090909
# 7        0.604167  26.645833   3.892342  0.520833   2.697917  17.437500
# 8        1.000000  64.666667  17.777778  1.000000   3.666667  18.000000
# 9        0.384615  33.461538  14.628200  0.961538   3.230769  14.557692
#
#          occupation      rate  nbaffairs        awm   age_cats    ym_cats  \
# cluster
# 0          4.132353  3.397059   2.235294  22.719363  24.632353  18.573529
# 1          4.755556  3.822222   2.200000  30.822222  33.177778  19.533333
# 2          3.894737  4.324561   0.710526  19.402107  20.464912   1.464912
# 3          5.000000  3.333333   0.000000  58.444444  53.888889  19.333333
# 4          2.000000  3.880952   1.190476  20.631949  21.619048   7.297619
# 5          5.318841  3.855072   2.130435  22.695652  24.072464   9.753623
# 6          5.672727  3.781818   2.254545  21.545455  22.945455  15.563636
# 7          5.031250  4.145833   1.062500  22.753492  23.520833   3.385417
# 8          5.222222  4.000000   0.222222  46.888889  48.333333  17.333333
# 9          3.076923  3.903846   1.307692  18.833338  20.365385  14.538462
#
#          has_affair
# cluster
# 0          0.308824
# 1          0.333333
# 2          0.157895
# 3          0.000000
# 4          0.238095
# 5          0.318841
# 6          0.309091
# 7          0.229167
# 8          0.111111
# 9          0.269231

# %%
plt.scatter(data['age'], data['religious'], c=arr)
plt.colorbar()

# %%
_ = plt.hist(data['cluster'], 10)

# %%
from scipy.spatial.distance import pdist
from scipy.cluster.hierarchy import linkage, dendrogram

dists = pdist(data[0:50], metric="cosine")
links = linkage(dists, method="average")
plt.figure(figsize=(100, 30))
den = dendrogram(links)

# %%
data.iloc[10]
# Out:
# sex            1.0
# age           35.0
# ym            20.0
# child          1.0
# religious      2.0
# education     20.0
# occupation     7.0
# rate           2.0
# nbaffairs      0.0
# awm           15.0
# age_cats      15.0
# ym_cats       19.0
# has_affair     0.0
# cluster        6.0
# Name: 10, dtype: float64

# %%
data["awm"][20:40]
# Out:
# 20    20.0000
# 21    19.0000
# 22    18.0000
# 23    20.0000
# 24    35.0000
# 25    20.0000
# 26    23.0000
# 27    24.0000
# 28    24.0000
# 29    20.0000
# 30    18.0000
# 31    23.0000
# 32    22.0000
# 33    16.0000
# 34    31.0000
# 35    20.0000
# 36    19.0000
# 37    18.0000
# 38    19.0000
# 39    19.4169
# Name: awm, dtype: float64

# %%
wdata = pd.read_csv("https://raw.githubusercontent.com/AUP-CS2091/Week-10/master/scotch.csv")
wdata['district'] = wdata['district'].astype('category').cat.codes
wdata['region'] = wdata['region'].astype('category').cat.codes

# %%
from sklearn.cluster import KMeans
model = KMeans(12)
model.fit(wdata)
clusters = model.predict(wdata)
wdata['cluster'] = clusters

# %%
groups = wdata.groupby('cluster')
group1 = groups.get_group(0)
group2 = groups.get_group(1)
group3 = groups.get_group(2)
group4 = groups.get_group(3)
group5 = groups.get_group(4)
group6 = groups.get_group(5)
group7 = groups.get_group(6)
group8 = groups.get_group(7)
group9 = groups.get_group(8)
group10 = groups.get_group(9)
group11 = groups.get_group(10)
group12 = groups.get_group(11)

# %%
group1
# Out:
.p.gold  color.gold  color.o.gold  color.f.gold  \
# Bladnoch                       0           0             0             0
# Glen Scotia                    0           0             0             1
# Springbank                     0           1             0             0
# Springbank-Longrow             0           1             0             0
#
#                     color.bronze  color.p.amber   ...     islay  midland  \
# Bladnoch                       0              0   ...         0        0
# Glen Scotia                    0              0   ...         0        0
# Springbank                     0              0   ...         0        0
# Springbank-Longrow             0              0   ...         0        0
#
#                     spey  east  west  north   lowland  campbell  islands  \
# Bladnoch               0     0     0       0        1         0        0
# Glen Scotia            0     0     0       0        0         1        0
# Springbank             0     0     0       0        0         1        0
# Springbank-Longrow     0     0     0       0        0         1        0
#
#                     cluster
# Bladnoch                  2
# Glen Scotia               2
# Springbank                2
# Springbank-Longrow        2
#
# [4 rows x 84 columns]

# %%
group4
# Out:
#                  color.wyne  color.yellow  color.v.pale  color.pale  \
# Fettercairn               0             0             0           1
# Glenesk                   0             0             0           0
# Jura                      0             0             0           0
# Saint Magdalene           0             0             0           0
#
#                  color.p.gold  color.gold  color.o.gold  color.f.gold  \
# Fettercairn                 0           0             0             0
# Glenesk                     0           1             0             0
# Jura                        0           1             0             0
# Saint Magdalene             0           0             0             0
#
#                  color.bronze  color.p.amber   ...     islay  midland  spey  \
# Fettercairn                 0              0   ...         0        0     0
# Glenesk                     0              0   ...         0        0     0
# Jura                        0              0   ...         0        0     0
# Saint Magdalene             0              0   ...         0        0     0
#
#                  east  west  north   lowland  campbell  islands  cluster
# Fettercairn         1     0       0        0         0        0        3
# Glenesk             1     0       0        0         0        0        3
# Jura                0     0       0        0         0        1        3
# Saint Magdalene     0     0       0        1         0        0        3
#
# [4 rows x 84 columns]

# %%
group5
# Out:
#               color.wyne  color.yellow  color.v.pale  color.pale  \
# Ardmore                0             0             0           0
# Glen Mhor              0             0             0           0
# Glentauchers           1             0             0           0
# Inchmurrin             0             0             0           0
# Inverleven             0             0             0           0
# Ladyburn               1             0             0           0
#
#               color.p.gold  color.gold  color.o.gold  color.f.gold  \
# Ardmore                  1           0             0             0
# Glen Mhor                0           1             0             0
# Glentauchers             0           0             0             0
# Inchmurrin               0           0             0             1
# Inverleven               0           1             0             0
# Ladyburn                 0           0             0             0
#
#               color.bronze  color.p.amber   ...     islay  midland  spey  \
# Ardmore                  0              0   ...         0        0     1
# Glen Mhor                0              0   ...         0        0     1
# Glentauchers             0              0   ...         0        0     1
# Inchmurrin               0              0   ...         0        0     0
# Inverleven               0              0   ...         0        0     0
# Ladyburn                 0              0   ...         0        0     0
#
#               east  west  north   lowland  campbell  islands  cluster
# Ardmore          0     0       0        0         0        0        4
# Glen Mhor        0     0       0        0         0        0        4
# Glentauchers     0     0       0        0         0        0        4
# Inchmurrin       0     1       0        0         0        0        4
# Inverleven       0     0       0        1         0        0        4
# Ladyburn         0     0       0        1         0        0        4
#
# [6 rows x 84 columns]

# %%
group6
# Out:
#                color.wyne  color.yellow  color.v.pale  color.pale  \
# Cragganmore             0             0             0           0
# Highland Park           0             0             0           0
# Lagavulin               0             0             0           0
# Laphroaig               0             0             0           0
# Talisker                0             0             0           0
#
#                color.p.gold  color.gold  color.o.gold  color.f.gold  \
# Cragganmore               0           1             0             0
# Highland Park             0           0             0             0
# Lagavulin                 0           0             0             0
# Laphroaig                 0           0             0             1
# Talisker                  0           0             0             0
#
#                color.bronze  color.p.amber   ...     islay  midland  spey  \
# Cragganmore               0              0   ...         0        0     1
# Highland Park             0              0   ...         0        0     0
# Lagavulin                 0              1   ...         1        0     0
# Laphroaig                 0              0   ...         1        0     0
# Talisker                  0              0   ...         0        0     0
# Glenburgie               0   ...         0        0     1     0     0       0
# Glen Keith               0   ...         0        0     1     0     0       0
# Glenlochy                0   ...         0        0     0     0     1       0
# Kinclaith                0   ...         0        0     0     0     0       0
#
#              lowland  campbell  islands  cluster
# Balmenach          0         0        0        8
# Banff              0         0        0        8
# Ben Nevis          0         0        0        8
# Benriach           0         0        0        8
# Coleburn           0         0        0        8
# Convalmore         0         0        0        8
# Glen  Albyn        0         0        0        8
# Glenburgie         0         0        0        8
# Glen Keith         0         0        0        8
# Glenlochy          0         0        0        8
# Kinclaith          1         0        0        8
#
# [11 rows x 84 columns]

# %%
group10
# Out:
#             color.wyne  color.yellow  color.v.pale  color.pale  color.p.gold  \
# Balvenie             0             0             0           0             0
# Benrinnes            0             0             0           0             0
# Dallas Dhu           0             0             0           0             0
# Port Ellen           0             0             0           0             0
# Singleton            0             0             0           0             0
#
#             color.gold  color.o.gold  color.f.gold  color.bronze  \
# Balvenie             0             0             0             0
# Benrinnes            0             0             0             0
# Dallas Dhu           0             0             0             0
# Port Ellen           0             0             0             0
# Singleton            0             0             0             0
#
#             color.p.amber   ...     islay  midland  spey  east  west  north   \
# Balvenie                0   ...         0        0     1     0     0       0
# Benrinnes               0   ...         0        0     1     0     0       0
# Dallas Dhu              0   ...         0        0     1     0     0       0
# Port Ellen              0   ...         0        0     0     0     1       0
# Singleton               0   ...         0        0     1     0     0       0
#
#             lowland  campbell  islands  cluster
# Balvenie          0         0        0        9
# Benrinnes         0         0        0        9
# Dallas Dhu        0         0        0        9
# Port Ellen        0         0        0        9
# Singleton         0         0        0        9
#
# [5 rows x 84 columns]

# %%
group11
# Out:
#           color.wyne  color.yellow  color.v.pale  color.pale  color.p.gold  \
# Glenugie           0             0             0           0             0
#
#           color.gold  color.o.gold  color.f.gold  color.bronze  color.p.amber  \
# Glenugie           0             0             1             0              0
#
#            ...     islay  midland  spey  east  west  north   lowland  \
# Glenugie   ...         0        0     0     1     0       0        0
#
#           campbell  islands  cluster
# Glenugie         0        0       10
#
# [1 rows x 84 columns]

# %%
group12
# Out:
#               color.wyne  color.yellow  color.v.pale  color.pale  \
# Aberlour               0             0             0           0
# Ardberg                0             0             0           0
# Auchentoshan           0             0             0           0
# Glenfarclas            0             0             0           0
# Glenlivet              0             0             0           0
# Glenrothes             0             0             0           0
# Linkwood               0             0             0           0
# Littlemill             1             0             0           0
# Longmorn               0             0             0           0
# Macallan               0             0             0           0
# Mortlach               0             0             0           0
# Strathisla             0             0             0           0
#
#               color.p.gold  color.gold  color.o.gold  color.f.gold  \
# Aberlour                 0           0             0             0
# Ardberg                  0           0             0             0
# Auchentoshan             1           0             0             0
# Glenfarclas              0           0             0             0
# Glenlivet                1           0             0             0
# Glenrothes               0           0             0             1
# Linkwood                 0           0             0             1
# Littlemill               0           0             0             0
# Longmorn                 0           0             0             1
# Macallan                 0           0             0             0
# Mortlach                 0           0             0             0
# Strathisla               0           0             0             0
#
#               color.bronze  color.p.amber   ...     islay  midland  spey  \
# Aberlour                 0              0   ...         0        0     1
# Ardberg                  0              0   ...         1        0     0
# Auchentoshan             0              0   ...         0        0     0
# Glenfarclas              1              0   ...         0        0     1
# Glenlivet                0              0   ...         0        0     1
# Glenrothes               0              0   ...         0        0     1
# Linkwood                 0              0   ...         0        0     1
# Littlemill               0              0   ...         0        0     0
# Longmorn                 0              0   ...         0        0     1
# Macallan                 0              0   ...         0        0     1
# Mortlach                 0              1   ...         0        0     1
# Strathisla               0              0   ...         0        0     1
#
#               east  west  north   lowland  campbell  islands  cluster
# Aberlour         0     0       0        0         0        0       11
# Ardberg          0     0       0        0         0        0       11
# Auchentoshan     0     0       0        1         0        0       11
# Glenfarclas      0     0       0        0         0        0       11
# Glenlivet        0     0       0        0         0        0       11
# Glenrothes       0     0       0        0         0        0       11
# Linkwood         0     0       0        0         0        0       11
# Littlemill       0     0       0        1         0        0       11
# Longmorn         0     0       0        0         0        0       11
# Macallan         0     0       0        0         0        0       11
# Mortlach         0     0       0        0         0        0       11
# Strathisla       0     0       0        0         0        0       11
#
# [12 rows x 84 columns]

# %%
wdata.apply(lambda x: 1 if x['cluster'] == 0
    else 0, axis = 1)
# Out:
# Aberfeldy             0
# Aberlour              0
# Ardberg               0
# Ardmore               0
# Auchentoshan          0
# Aultmore              1
# Balblair              0
# Balmenach             0
# Balvenie              0
# Banff                 0
# Ben Nevis             0
# Benriach              0
# Benrinnes             0
# Benromach             0
# Bladnoch              0
# Blair Athol           0
# Bowmore               0
# Brackla               0
# Bruichladdich         0
# Bunnahabhain          0
# Caol Ila              0
# Caperdonich           0
# Cardhu                1
# Clynelish             0
# Coleburn              0
# Convalmore            0
# Cragganmore           0
# Craigellachie         0
# Dailuaine             0
# Dallas Dhu            0
#                      ..
# Linkwood              0
# Littlemill            0
# Lochnagar             0
# Lochside              0
# Longmorn              0
# Macallan              0
# Millburn              0
# Miltonduff            1
# Mortlach              0
# North Port            0
# Oban                  1
# Port Ellen            0
# Pulteney              0
# Rosebank              0
# Saint Magdalene       0
# Scapa                 0
# Singleton             0
# Speyburn              0
# Springbank            0
# Springbank-Longrow    0
# Strathisla            0
# Talisker              0
# Tamdhu                1
# Tamnavulin            1
# Teaninich             0
# Tobermory             0
# Tomatin               1
# Tomintoul             1
# Tormore               1
# Tullibardine          0
# Length: 109, dtype: int64

# %%
X = wdata[['region', 'district']]

Y = wdata['cluster']

from sklearn import tree

clf = tree.DecisionTreeClassifier(criterion='entropy',max_depth=8)
clf = clf.fit(X, Y)
import graphviz 
dot_data = tree.export_graphviz(clf, out_file=None, 
                         feature_names=X.columns.values,  
                         filled=True, rounded=True,  
                         special_characters=True) 
graph = graphviz.Source(dot_data) 
graph

# %%
adata = pd.read_csv("https://github.com/AUP-CS2091/Week-10/blob/master/animals.csv")
adata
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c9309979de40> in <module>()
# ----> 1 adata = pd.read_csv("https://github.com/AUP-CS2091/Week-10/blob/master/animals.csv")
#       2 adata
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## Conclusion
#
# I have tried to find the likelihood of a person to have an extramarital affair taking into accounts different features. After trying out all techniques learned in class, my conclusion is that ...
